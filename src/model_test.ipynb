# %%
import os
import vae.vae_utils
import visualize
import numpy as np

# %%
test = vae.vae_utils.load_vae_model(
    vae_type="vae_conv", 
    dir_path="C:/Users/biberd/Documents/SurfaceEvents/Story 9999/timeVAE/outputs/models/sample_classified_data/vae_conv_sample_classified_data_1748011747"
    )
# Out:
# WARNING:tensorflow:From c:\Users\biberd\Documents\SurfaceEvents\Story 9999\timeVAE\vae310\lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %%
num_samples = 50000
samples = test.get_prior_samples(num_samples=num_samples)
np.savez("synthetic_data.npz", samples)

# %%
num_samples = 5
samples = test.get_prior_samples(num_samples=num_samples)
visualize.plot_samples(
    samples1=samples,
    samples1_name="VAE_Conv Samples",
    num_samples=num_samples
)
